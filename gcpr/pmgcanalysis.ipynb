# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pmgc.csv')

# %%
df
# Out:
#     Match  Day      Map Winner  Rank        Land spot       Final Zone  \
# 0       1    1   Sanhok    FLC     1         Bootcamp           Quarry
# 1       2    1  Erangel    NGX     1         Pochinki            Gatka
# 2       3    1  Erangel  TSPRT     4             Farm    Military Base
# 3       4    1  Erangel    4MV     1    Military Base    Military Base
# 4       5    1  Miramar  TSPRT     2           Pecado      Monte Nuevo
# 5       6    1  Miramar     DK     4        El Azahar  Minas Generales
# 6       7    2   Sanhok    RCB     6          Tat Mok  Paradise Resort
# 7       8    2  Erangel    INF     6       Ferry Pier         Pochinki
# 8       9    2  Erangel    DRX     9           Ghatka           School
# 9      10    2  Erangel    RCB     1            Ruins          Mansion
# 10     11    2  Miramar    TJB    10      Monte Nuevo       La Bendita
# 11     12    2  Miramar     DK     2       Los Leones       San Martin
# ...

# %%
df.head()
# Out:
#    Match  Day      Map Winner  Rank      Land spot     Final Zone Rotation  \
# 0      1    1   Sanhok    FLC     1       Bootcamp         Quarry    Short
# 1      2    1  Erangel    NGX     1       Pochinki          Gatka    Short
# 2      3    1  Erangel  TSPRT     4           Farm  Military Base   Medium
# 3      4    1  Erangel    4MV     1  Military Base  Military Base    Short
# 4      5    1  Miramar  TSPRT     2         Pecado    Monte Nuevo    Short
#
#    Total Kill  Total Point       MVP  Player Remaining Fav Weapon Runner Up
# 0          11           21       Top                 3       M416       4MV
# 1          10           20  Narvalow                 4       S12K        VD
# 2          11           21    Knowme                 4      SCARL       DRX
# 3          23           33       Dok                 4       M416        VC
# 4           5           15    Knowme                 4       M416       RCB

# %%
df.describe()
# Out:
#            Match        Day       Rank  Total Kill  Total Point  \
# count  18.000000  18.000000  18.000000   18.000000    18.000000
# mean    9.500000   2.000000   4.277778   11.277778    21.222222
# std     5.338539   0.840168   3.967598    4.860471     4.893640
# min     1.000000   1.000000   1.000000    5.000000    15.000000
# 25%     5.250000   1.000000   1.000000    8.250000    18.000000
# 50%     9.500000   2.000000   2.000000   11.000000    21.000000
# 75%    13.750000   3.000000   6.000000   12.750000    22.750000
# max    18.000000   3.000000  13.000000   23.000000    33.000000
#
#        Player Remaining
# count         18.000000
# mean           3.666667
# std            0.485071
# min            3.000000
# 25%            3.000000
# 50%            4.000000
# 75%            4.000000
# max            4.000000

# %%
df.sort_values(by = 'Total Kill', ascending = False)
# Out:
#     Match  Day      Map Winner  Rank        Land spot       Final Zone  \
# 3       4    1  Erangel    4MV     1    Military Base    Military Base
# 9      10    2  Erangel    RCB     1            Ruins          Mansion
# 15     16    3  Erangel     A7    11        Georgopol          Shelter
# 16     17    3  Miramar     TT    13        Graveyard        El Azahar
# 7       8    2  Erangel    INF     6       Ferry Pier         Pochinki
# 5       6    1  Miramar     DK     4        El Azahar  Minas Generales
# 13     14    3  Erangel    NGX     1         Pochinki        Georgopol
# 10     11    2  Miramar    TJB    10      Monte Nuevo       La Bendita
# 0       1    1   Sanhok    FLC     1         Bootcamp           Quarry
# 2       3    1  Erangel  TSPRT     4             Farm    Military Base
# 1       2    1  Erangel    NGX     1         Pochinki            Gatka
# 8       9    2  Erangel    DRX     9           Ghatka           School
# ...
